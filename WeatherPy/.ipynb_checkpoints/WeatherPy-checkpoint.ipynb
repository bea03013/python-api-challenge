# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\mjbgo\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\mjbgo\anaconda3\lib\site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress


# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "OutputData/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 618

# %% [markdown]
# ## Perform API Calls
# ##### Perform a weather check on each city using a series of successive API calls.
# ##### Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"----------------------------------------------------------")
print(f"Beginning Data Retrieval")
print(f"----------------------------------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# ----------------------------------------------------------
# Beginning Data Retrieval
# ----------------------------------------------------------
# Processing Record 1 | Mariakani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=mariakani
# Processing Record 2 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=atuona
# Processing Record 3 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=lompoc
# Processing Record 4 | Berlevåg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=berlevag
# Processing Record 5 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=barrow
# Processing Record 6 | Karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=karratha
# Processing Record 7 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=rikitea
# Processing Record 8 | Ternate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ternate
# City not found. Skipping...
# Processing Record 9 | George Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=georgetown
# Processing Record 10 | Luganville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=luganville
# Processing Record 11 | Skibbereen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=skibbereen
# Processing Record 12 | Mbekenyera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=mbekenyera
# Processing Record 13 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=hermanus
# Processing Record 14 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ushuaia
# Processing Record 15 | Bahār
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bahar
# Processing Record 16 | Mahébourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=mahebourg
# Processing Record 17 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=jamestown
# Processing Record 18 | Lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=lagoa
# Processing Record 19 | Saint Paul Harbor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kodiak
# Processing Record 20 | Sukhobuzimskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=sukhobuzimskoye
# Processing Record 21 | Navoiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=navoi
# Processing Record 22 | Bereda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bereda
# Processing Record 23 | Yahualica de González Gallo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=yahualica
# Processing Record 24 | Tabou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tabou
# Processing Record 25 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tasiilaq
# Processing Record 26 | Brookings
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=brookings
# Processing Record 27 | Asău
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=asau
# Processing Record 28 | Kumul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=hami
# Processing Record 29 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=puerto ayora
# Processing Record 30 | Matara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=matara
# Processing Record 31 | Madingou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=madingou
# Processing Record 32 | Quelimane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=quelimane
# Processing Record 33 | Mossamedes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=namibe
# Processing Record 34 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=mataura
# Processing Record 35 | Camocim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=camocim
# Processing Record 36 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=avarua
# Processing Record 37 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=dikson
# Processing Record 38 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bluff
# Processing Record 39 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=mar del plata
# Processing Record 40 | Pratāpgarh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=pratapgarh
# Processing Record 41 | Sechura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=sechura
# Processing Record 42 | Port Hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=port hedland
# Processing Record 43 | Puerto Escondido
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=puerto escondido
# Processing Record 44 | Siocon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=siocon
# Processing Record 45 | Krasnosel'kup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=krasnoselkup
# Processing Record 46 | Isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=isangel
# Processing Record 47 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=cabo san lucas
# Processing Record 48 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=upernavik
# Processing Record 49 | Wattegama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=wattegama
# City not found. Skipping...
# Processing Record 50 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=qaanaaq
# Processing Record 51 | Nyurba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=nyurba
# Processing Record 52 | Tonkino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tonkino
# Processing Record 53 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=airai
# Processing Record 54 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ribeira grande
# Processing Record 55 | Port-Cartier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=port-cartier
# Processing Record 56 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=yellowknife
# Processing Record 57 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=hobart
# Processing Record 58 | Atkinson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=atkinson
# Processing Record 59 | Merauke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=merauke
# Processing Record 60 | Sakaiminato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=sakaiminato
# Processing Record 61 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tuatapere
# Processing Record 62 | Xiaoweizhai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=xiaoweizhai
# Processing Record 63 | Warrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=warrington
# Processing Record 64 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=longyearbyen
# Processing Record 65 | Pimentel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=pimentel
# Processing Record 66 | Sungai Raya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=sungairaya
# Processing Record 67 | Constitución
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=constitucion
# Processing Record 68 | Tocopilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tocopilla
# City not found. Skipping...
# Processing Record 69 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=nanortalik
# Processing Record 70 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kaitangata
# Processing Record 71 | Langsa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=langsa
# Processing Record 72 | Ordu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ordu
# Processing Record 73 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=khatanga
# Processing Record 74 | Kapiri Mposhi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kapiri mposhi
# Processing Record 75 | Mullovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=mullovka
# Processing Record 76 | Makat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=makat
# Processing Record 77 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bethel
# Processing Record 78 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=thompson
# Processing Record 79 | Loralai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=loralai
# Processing Record 80 | Boundiali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=boundiali
# Processing Record 81 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=punta arenas
# Processing Record 82 | Chernyshevskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=chernyshevskiy
# Processing Record 83 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bredasdorp
# Processing Record 84 | Arawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=arawa
# Processing Record 85 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=hithadhoo
# Processing Record 86 | Viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=viedma
# Processing Record 87 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=east london
# Processing Record 88 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=cape town
# Processing Record 89 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=new norfolk
# Processing Record 90 | Río Gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=rio gallegos
# Processing Record 91 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=iqaluit
# Processing Record 92 | Hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=hofn
# Processing Record 93 | Tabora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tabora
# Processing Record 94 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=saint george
# Processing Record 95 | Tual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tual
# Processing Record 96 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=fortuna
# Processing Record 97 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=port alfred
# Processing Record 98 | Changuinola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=changuinola
# Processing Record 99 | Ruteng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ruteng
# City not found. Skipping...
# Processing Record 100 | Shelburne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=shelburne
# Processing Record 101 | Mattru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=mattru
# Processing Record 102 | Upington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=upington
# Processing Record 103 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=albany
# Processing Record 104 | Huilong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=huilong
# Processing Record 105 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=pevek
# Processing Record 106 | Xingtai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=xingtai
# Processing Record 107 | Gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=gamba
# Processing Record 108 | Kholtoson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kholtoson
# Processing Record 109 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tuktoyaktuk
# City not found. Skipping...
# Processing Record 110 | Hay River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=hay river
# Processing Record 111 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kavieng
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 112 | Pampa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=pampa
# Processing Record 113 | Evensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=evensk
# Processing Record 114 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=carnarvon
# Processing Record 115 | Lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=lincoln
# Processing Record 116 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=lorengau
# Processing Record 117 | Ngunguru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ngunguru
# City not found. Skipping...
# Processing Record 118 | Urucará
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=urucara
# Processing Record 119 | Fort Saint James
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=fort saint james
# Processing Record 120 | Rakaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=rakaia
# Processing Record 121 | Olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=olafsvik
# Processing Record 122 | Buckeye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=buckeye
# Processing Record 123 | San Quintín
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=san quintin
# Processing Record 124 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kapaa
# Processing Record 125 | Zelenogorskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=zelenogorskiy
# City not found. Skipping...
# Processing Record 126 | Muncar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=muncar
# Processing Record 127 | Dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=dingle
# Processing Record 128 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=arraial do cabo
# Processing Record 129 | Morón
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=moron
# Processing Record 130 | Burns Lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=burns lake
# Processing Record 131 | Mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=mayo
# City not found. Skipping...
# Processing Record 132 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=saskylakh
# Processing Record 133 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=busselton
# Processing Record 134 | Salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=salalah
# Processing Record 135 | Myitkyina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=myitkyina
# Processing Record 136 | Ajdabiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ajdabiya
# Processing Record 137 | Wollongong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=wollongong
# Processing Record 138 | Verāval
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=veraval
# Processing Record 139 | Marabu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=miri
# Processing Record 140 | Ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ketchikan
# Processing Record 141 | Frontera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=frontera
# Processing Record 142 | Tenneville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tenneville
# Processing Record 143 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=hilo
# Processing Record 144 | Livingston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=livingston
# Processing Record 145 | Severo-Kuril'sk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=severo-kurilsk
# Processing Record 146 | Sakakah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=sakakah
# Processing Record 147 | Ulaangom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ulaangom
# Processing Record 148 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=chokurdakh
# Processing Record 149 | Bara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bara
# Processing Record 150 | Shambu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=shambu
# Processing Record 151 | Gogrial
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=gogrial
# Processing Record 152 | Buraidah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=buraydah
# Processing Record 153 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=cherskiy
# City not found. Skipping...
# Processing Record 154 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=saint-philippe
# Processing Record 155 | Riohacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=riohacha
# Processing Record 156 | Ust'-Uda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ust-uda
# Processing Record 157 | Atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=atar
# Processing Record 158 | Saint-Augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=saint-augustin
# Processing Record 159 | Marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=marawi
# Processing Record 160 | Bang Saphan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bang saphan
# Processing Record 161 | Dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=dunedin
# Processing Record 162 | Vallenar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=vallenar
# Processing Record 163 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=castro
# City not found. Skipping...
# Processing Record 164 | Ust-Kuyga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ust-kuyga
# Processing Record 165 | Paka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=paka
# Processing Record 166 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ahipara
# Processing Record 167 | Baruun-Urt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=baruun-urt
# Processing Record 168 | Carpinteria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=carpinteria
# City not found. Skipping...
# Processing Record 169 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ponta do sol
# Processing Record 170 | Jeremoabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=jeremoabo
# City not found. Skipping...
# Processing Record 171 | Jalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=jalu
# Processing Record 172 | Cikupa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=cikupa
# Processing Record 173 | Shizunai-furukawachō
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=shizunai
# Processing Record 174 | Diego de Almagro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=diego de almagro
# Processing Record 175 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=esperance
# Processing Record 176 | Mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=mitsamiouli
# Processing Record 177 | Altamont
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=altamont
# Processing Record 178 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=clyde river
# City not found. Skipping...
# Processing Record 179 | Itainópolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=itainopolis
# Processing Record 180 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bambous virieux
# Processing Record 181 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=butaritari
# Processing Record 182 | Hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=hamilton
# Processing Record 183 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kruisfontein
# Processing Record 184 | Boyolangu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=boyolangu
# Processing Record 185 | Muli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=muli
# Processing Record 186 | Borisoglebskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=borisoglebskiy
# Processing Record 187 | Husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=husavik
# City not found. Skipping...
# Processing Record 188 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=geraldton
# Processing Record 189 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=torbay
# Processing Record 190 | Mahibadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=mahibadhoo
# Processing Record 191 | Namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=namatanai
# Processing Record 192 | Greenfield
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=greenfield
# Processing Record 193 | Leh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=leh
# Processing Record 194 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=nikolskoye
# Processing Record 195 | Pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=pisco
# Processing Record 196 | Quatre Cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=quatre cocos
# Processing Record 197 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=vaini
# Processing Record 198 | Aljezur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=aljezur
# Processing Record 199 | Atherton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=atherton
# City not found. Skipping...
# Processing Record 200 | Bonavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bonavista
# Processing Record 201 | Zaysan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=zaysan
# Processing Record 202 | Sangar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=sangar
# Processing Record 203 | Futtsu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=futtsu
# Processing Record 204 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=norman wells
# Processing Record 205 | Kisangani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kisangani
# Processing Record 206 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=hasaki
# Processing Record 207 | Beidao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=beidao
# City not found. Skipping...
# Processing Record 208 | Portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=portland
# Processing Record 209 | Ryōtsu-minato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ryotsu
# Processing Record 210 | Nanning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=nanning
# Processing Record 211 | Baião
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=baiao
# Processing Record 212 | Lüderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=luderitz
# Processing Record 213 | Assiniboia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=assiniboia
# Processing Record 214 | Smithers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=smithers
# Processing Record 215 | Faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=faya
# Processing Record 216 | Alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=alofi
# Processing Record 217 | Rivera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=rivera
# City not found. Skipping...
# Processing Record 218 | Demyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=demyansk
# Processing Record 219 | Nizhnevartovsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=nizhnevartovsk
# Processing Record 220 | Tarata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tarata
# Processing Record 221 | La Ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=la ronge
# Processing Record 222 | Hong Kong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=victoria
# Processing Record 223 | Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ostrovnoy
# Processing Record 224 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=aklavik
# Processing Record 225 | Nambucca Heads
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=nambucca heads
# Processing Record 226 | Port-Gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=port-gentil
# Processing Record 227 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tiksi
# Processing Record 228 | Aksu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=aksu
# Processing Record 229 | Cedar City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=cedar city
# Processing Record 230 | Shīeli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=shieli
# Processing Record 231 | Verkhneural'sk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=verkhneuralsk
# City not found. Skipping...
# Processing Record 232 | Bedēsa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bedesa
# Processing Record 233 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=port elizabeth
# Processing Record 234 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=port lincoln
# Processing Record 235 | Japura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=japura
# City not found. Skipping...
# Processing Record 236 | Karoi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=karoi
# Processing Record 237 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=saldanha
# Processing Record 238 | Kānt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kant
# Processing Record 239 | Okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=okhotsk
# Processing Record 240 | Sabha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=sabha
# Processing Record 241 | Maţāy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=matay
# Processing Record 242 | College
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=college
# Processing Record 243 | Talcahuano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=talcahuano
# Processing Record 244 | Belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=belmonte
# Processing Record 245 | Arman'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=arman
# City not found. Skipping...
# Processing Record 246 | Chara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=chara
# Processing Record 247 | São Filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=sao filipe
# Processing Record 248 | Vardø
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=vardo
# Processing Record 249 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=los llanos de aridane
# Processing Record 250 | Savannah Bight
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=savannah bight
# City not found. Skipping...
# Processing Record 251 | Antalaha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=antalaha
# City not found. Skipping...
# Processing Record 252 | Gravdal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=gravdal
# Processing Record 253 | Diu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=diu
# Processing Record 254 | Gezing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=gezing
# Processing Record 255 | Lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=lata
# Processing Record 256 | Qandala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=qandala
# Processing Record 257 | Aksha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=aksha
# City not found. Skipping...
# Processing Record 258 | Umm Kaddadah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=umm kaddadah
# Processing Record 259 | Comodoro Rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=comodoro rivadavia
# Processing Record 260 | Rawlins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=rawlins
# Processing Record 261 | Marquette
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=marquette
# Processing Record 262 | Porbandar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=porbandar
# Processing Record 263 | Yichang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=yichang
# Processing Record 264 | Cachoeira do Sul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=cachoeira do sul
# Processing Record 265 | Vieques
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=vieques
# Processing Record 266 | Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=vila franca do campo
# Processing Record 267 | Biak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=biak
# Processing Record 268 | Mount Isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=mount isa
# Processing Record 269 | Sumbe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=sumbe
# Processing Record 270 | Nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=nouadhibou
# Processing Record 271 | Payette
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=payette
# Processing Record 272 | Englewood
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=englewood
# Processing Record 273 | Mosquera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=mosquera
# Processing Record 274 | Christchurch
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=christchurch
# Processing Record 275 | Shirokiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=shirokiy
# Processing Record 276 | Ust'-Ishim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ust-ishim
# Processing Record 277 | Bequimão
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bequimao
# Processing Record 278 | Samandağ
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=samandag
# Processing Record 279 | Dogondoutchi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=dogondoutchi
# Processing Record 280 | Paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=paamiut
# Processing Record 281 | Manokwari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=manokwari
# Processing Record 282 | Carutapera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=carutapera
# Processing Record 283 | Cap-aux-Meules
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=cap-aux-meules
# Processing Record 284 | Mahon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=mahon
# City not found. Skipping...
# Processing Record 285 | Laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=laguna
# Processing Record 286 | Poso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=poso
# Processing Record 287 | Stepnyak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=stepnyak
# City not found. Skipping...
# Processing Record 288 | Santa Maria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=santa maria
# Processing Record 289 | Caramay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=caramay
# Processing Record 290 | Richards Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=richards bay
# Processing Record 291 | Gemeente Wageningen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=wageningen
# Processing Record 292 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=san patricio
# Processing Record 293 | Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=lavrentiya
# Processing Record 294 | Udomlya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=udomlya
# Processing Record 295 | Cabo Rojo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=cabo rojo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 296 | Robertsport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=robertsport
# Processing Record 297 | Namie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=namie
# Processing Record 298 | Misratah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=misratah
# Processing Record 299 | Tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tessalit
# Processing Record 300 | Teguise
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=teguise
# Processing Record 301 | Jasper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=jasper
# Processing Record 302 | Meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=meulaboh
# City not found. Skipping...
# Processing Record 303 | Cockburn Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=cockburn town
# Processing Record 304 | Candelaria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=candelaria
# Processing Record 305 | Gusau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=gusau
# Processing Record 306 | Bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bambanglipuro
# Processing Record 307 | Izumo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=izumo
# Processing Record 308 | Weihe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=weihe
# City not found. Skipping...
# Processing Record 309 | Strezhevoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=strezhevoy
# Processing Record 310 | Pacific Grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=pacific grove
# Processing Record 311 | Belgrade
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=belgrade
# Processing Record 312 | Polovinnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=polovinnoye
# City not found. Skipping...
# Processing Record 313 | Iturama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=iturama
# City not found. Skipping...
# Processing Record 314 | Beāwar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=beawar
# City not found. Skipping...
# Processing Record 315 | Bakel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bakel
# Processing Record 316 | San Antonio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=san antonio
# Processing Record 317 | Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=saint-pierre
# Processing Record 318 | Taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=taoudenni
# Processing Record 319 | Sembakung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=sembakung
# Processing Record 320 | Anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=anadyr
# Processing Record 321 | Yeppoon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=yeppoon
# City not found. Skipping...
# Processing Record 322 | Paraná
# ...
# Processing Record 451 | Biankouma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=biankouma
# Processing Record 452 | Twentynine Palms
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=twentynine palms
# Processing Record 453 | Safi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=asfi
# City not found. Skipping...
# Processing Record 454 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=caravelas
# Processing Record 455 | Maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=maragogi
# Processing Record 456 | Beroroha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=beroroha
# City not found. Skipping...
# Processing Record 457 | Kondopoga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kondopoga
# Processing Record 458 | Rutana Province
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=rutana
# Processing Record 459 | Herat Province
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=herat
# Processing Record 460 | Bagar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bagar
# Processing Record 461 | Zaria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=zaria
# Processing Record 462 | Kjøllefjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kjollefjord
# Processing Record 463 | Chibombo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=chibombo
# Processing Record 464 | Ténenkou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tenenkou
# Processing Record 465 | Kokopo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kokopo
# Processing Record 466 | Enshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=enshi
# Processing Record 467 | Temerloh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=temerloh
# Processing Record 468 | Omboué
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=omboue
# City not found. Skipping...
# Processing Record 469 | Linxia Chengguanzhen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=linxia
# Processing Record 470 | Luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=luanda
# Processing Record 471 | Rāmhormoz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ramhormoz
# Processing Record 472 | Coachella
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=coachella
# Processing Record 473 | Biloela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=biloela
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 474 | Cabinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=cabinda
# Processing Record 475 | Jämsä
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=jamsa
# Processing Record 476 | Pāsighāt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=pasighat
# Processing Record 477 | Bontang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bontang
# Processing Record 478 | Bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bengkulu
# Processing Record 479 | Talladega
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=talladega
# Processing Record 480 | Banda Aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=banda aceh
# Processing Record 481 | Trofors
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=trofors
# Processing Record 482 | Araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=araouane
# Processing Record 483 | Lázaro Cárdenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=lazaro cardenas
# City not found. Skipping...
# Processing Record 484 | Grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=grindavik
# Processing Record 485 | Mollendo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=mollendo
# Processing Record 486 | Coolum Beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=coolum beach
# Processing Record 487 | Weihai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=weihai
# Processing Record 488 | Bahía Blanca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bahia blanca
# Processing Record 489 | Collingwood
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=collingwood
# Processing Record 490 | Juneau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=juneau
# Processing Record 491 | Nova Olímpia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=nova olimpia
# Processing Record 492 | Melfi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=melfi
# Processing Record 493 | Nacala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=nacala
# Processing Record 494 | Tierra Nueva
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tierranueva
# Processing Record 495 | Touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=touros
# Processing Record 496 | Praia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=praya
# Processing Record 497 | Johi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=johi
# Processing Record 498 | Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=srednekolymsk
# City not found. Skipping...
# Processing Record 499 | Nizwá
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=nizwa
# Processing Record 500 | Kabare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kabare
# Processing Record 501 | Martapura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=martapura
# Processing Record 502 | Zion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=zion
# Processing Record 503 | San Rafael
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=san rafael
# Processing Record 504 | Kargopol'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kargopol
# Processing Record 505 | Broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=broome
# Processing Record 506 | Vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=vanimo
# Processing Record 507 | Havre-St-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=havre-saint-pierre
# Processing Record 508 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=narsaq
# Processing Record 509 | Nizhny Novgorod
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=nizhniy novgorod
# Processing Record 510 | Verkhnyaya Toyma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=verkhnyaya toyma
# Processing Record 511 | Poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=poum
# Processing Record 512 | Talaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=talaya
# Processing Record 513 | Soyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=soyo
# Processing Record 514 | Fort Nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=fort nelson
# Processing Record 515 | Korla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=korla
# Processing Record 516 | LaBelle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=labelle
# Processing Record 517 | Santiago del Estero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=santiago del estero
# Processing Record 518 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=vila velha
# Processing Record 519 | Padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=padang
# City not found. Skipping...
# Processing Record 520 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kavaratti
# Processing Record 521 | Kazanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kazanka
# Processing Record 522 | Point Pleasant
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=point pleasant
# Processing Record 523 | Shibetsu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=shibetsu
# Processing Record 524 | Talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=talnakh
# Processing Record 525 | Sørland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=sorland
# Processing Record 526 | Kazachinskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kazachinskoye
# Processing Record 527 | Novovasylivka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=novovasylivka
# Processing Record 528 | Erenhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=erenhot
# Processing Record 529 | Nova Londrina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=nova londrina
# City not found. Skipping...
# Processing Record 530 | Takapau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=takapau
# Processing Record 531 | Nalbant
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=nalbant
# Processing Record 532 | Kiryat Gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=gat
# Processing Record 533 | Waingapu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=waingapu
# City not found. Skipping...
# Processing Record 534 | Qurayyat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=qurayyat
# Processing Record 535 | Kindu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kindu
# Processing Record 536 | Örnsköldsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ornskoldsvik
# Processing Record 537 | Kirovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kirovskiy
# Processing Record 538 | Teplá
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tepla
# Processing Record 539 | Arefu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=arefu
# Processing Record 540 | Tūkrah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tukrah
# Processing Record 541 | Alta Floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=alta floresta
# Processing Record 542 | Belaya Gora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=belaya gora
# Processing Record 543 | Waddān
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=waddan
# Processing Record 544 | Moengo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=moengo
# Processing Record 545 | Hirara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=hirara
# Processing Record 546 | Plouzané
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=plouzane
# Processing Record 547 | Ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ixtapa
# Processing Record 548 | Abu Dhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=abu dhabi
# Processing Record 549 | Yaan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=yaan
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 550 | Hokitika
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=hokitika
# Processing Record 551 | Matamoros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=matamoros
# Processing Record 552 | Yarmouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=yarmouth
# Processing Record 553 | Casper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=casper
# Processing Record 554 | Ushtobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ushtobe
# City not found. Skipping...
# Processing Record 555 | Buctzotz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=buctzotz
# Processing Record 556 | Conakry
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=conakry
# Processing Record 557 | Semey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=semey

# %% [markdown]
# ## Convert Raw Data to DataFrame
# ##### Export the city data into a .csv.
# ##### Display the DataFrame

# %%
# Create a dictonary with the lists generated
weatherpy_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a data frame from dictionary
weather_df = pd.DataFrame(weatherpy_dict)

# Display count of weather data values to look for any missing data...looks like we're good! 
weather_df.count()
# Out:
# City          557
# Cloudiness    557
# Country       557
# Date          557
# Humidity      557
# Lat           557
# Lng           557
# Max Temp      557
# Wind Speed    557
# dtype: int64

# %%
# Save data frame to CSV
weather_df.to_csv('OutputData/weather_data.csv')

# Display data frame head 
weather_df.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  Mariakani           1      KE  1591735074        94  -3.86   39.47
# 1     Atuona           8      PF  1591735075        78  -9.80 -139.03
# 2     Lompoc           1      US  1591735076        28  34.64 -120.46
# 3   Berlevåg          75      NO  1591735077        60  70.86   29.09
# 4     Barrow          90      US  1591735079        80  71.29 -156.79
#
#    Max Temp  Wind Speed
# 0     70.09        5.86
# 1     80.85       21.88
# 2     93.20       17.22
# 3     42.80        9.17
# 4     30.20        5.82

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ##### Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
#First sort descending by Humidty
humidity_df = weather_df.sort_values(["Humidity"], ascending=False)
humidity_df.head()
# Out:
#                 City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 19   Sukhobuzimskoye          40      RU  1591735095       100  56.50   93.27
# 52             Airai          82      TL  1591735132       100  -8.93  125.41
# 36            Dikson         100      RU  1591735114       100  73.51   80.55
# 273     Christchurch          27      NZ  1591735231       100 -43.53  172.63
# 74          Mullovka           8      RU  1591735157       100  54.20   49.40
#
#      Max Temp  Wind Speed
# 19      41.00        6.71
# 52      56.59        3.69
# 36      34.36       11.74
# 273     30.20        2.24
# 74      60.80        4.47

# %% [markdown]
# #### It looks like there are no cities with a humidity over 100...so we can skip the next step!

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

clean_city_df = weather_df

clean_city_df.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  Mariakani           1      KE  1591735074        94  -3.86   39.47
# 1     Atuona           8      PF  1591735075        78  -9.80 -139.03
# 2     Lompoc           1      US  1591735076        28  34.64 -120.46
# 3   Berlevåg          75      NO  1591735077        60  70.86   29.09
# 4     Barrow          90      US  1591735079        80  71.29 -156.79
#
#    Max Temp  Wind Speed
# 0     70.09        5.86
# 1     80.85       21.88
# 2     93.20       17.22
# 3     42.80        9.17
# 4     30.20        5.82

# %%
# Extract relevant fields from the data frame
clean_city_df = clean_city_df[["City", "Country", "Cloudiness", "Humidity", "Lat", "Lng", "Max Temp", "Wind Speed"]]


# Export the City_Data into a csv
clean_city_df.to_csv("OutputData/CleanCityData.csv", index=True, header=True)

# %% [markdown]
# ## Plotting the Data
# ##### Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# ##### Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature

# %%
# Build a scatter plot for each data type
plt.scatter(clean_city_df["Lat"], clean_city_df["Max Temp"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("OutputData/Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ##### This code is analyzing the relationship between the Latitude and the Max Temperature. It appears to show that max temperature peaks around 20 degrees Latitude and then goes down the farther you get from there.

# %% [markdown]
# ## Latitude vs. Humidity

# %%
# Build a scatter plot for each data type
plt.scatter(clean_city_df["Lat"], clean_city_df["Humidity"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("OutputData/Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ##### This code is analyzing the relationship between the Latitude and the Humidity. It appears to show that there is no correlation between the two.

# %% [markdown]
# ## Latitude vs. Cloudiness

# %%
# Build a scatter plot for each data type
plt.scatter(clean_city_df["Lat"], clean_city_df["Cloudiness"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("OutputData/Cloudiness_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ##### This code is analyzing the relationship between the Latitude and the Cloudiness. It appears to show that there is no correlation between the two.

# %% [markdown]
# ## Latitude vs. Windspeed

# %%
# Build a scatter plot for each data type
plt.scatter(clean_city_df["Lat"], clean_city_df["Wind Speed"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("OutputData/Wind_Speed_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ##### This code is analyzing the relationship between the Latitude and the Max Temperature. It appears to show that there is no correlation between the two.

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames

northern_df = clean_city_df.loc[clean_city_df["Lat"] >= 0]
southern_df = clean_city_df.loc[clean_city_df["Lat"] < 0]

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def linear_regression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Define a fuction for annotating
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %% [markdown]
# #### Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(northern_df["Lat"], northern_df["Max Temp"])

# Call an function #2
annotate(equation, 10, 40)

# Set a title
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("OutputData/Max_Temp_vs_Latitude_Northern_Regression.png")
# Out:
# The r-squared is : -0.75

# %% [markdown]
# ##### This code is analyzing the relationship between the Latitude and the Max Temperature in the Norther Hemisphere. It appears to show that max temperature peaks around 20 degrees Latitude and then goes down the farther you get from there. The higher negative r value shows that there is a decent amount of correlation between the Latitude and the Max Temperature. The higher the Latitude, the lower the Max Temperature in general.

# %% [markdown]
# #### Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(southern_df["Lat"],southern_df["Max Temp"])

# Call an function #2
annotate(equation, -30, 50)

# Set a title
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("OutputData/Max_Temp_vs_Latitude_Southern_Regression.png")
# Out:
# The r-squared is : 0.79

# %% [markdown]
# ##### This code is analyzing the relationship between the Latitude and the Max Temperature in the Southern Hemisphere. It appears to show that max temperature peaks the closer to Latitude 0 degrees. The higher r value shows that there is a decent amount of correlation between the Latitude and the Max Temperature. The closer to 0 the Latitude gets, the higher the Max Temperature in general.

# %% [markdown]
# #### Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(northern_df["Lat"], northern_df["Humidity"])

# Call an function #2
annotate(equation, 40, 15)

# Set a title
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("OutputData/Humidity_vs_Latitude_Northern_Regression.png")
# Out:
# The r-squared is : 0.03

# %% [markdown]
# ##### This code is analyzing the relationship between the Latitude and the Humidity in the Northern Hemisphere. The low correlation shown suggests that there is no correlation between the Latitude and the Humidity.

# %% [markdown]
# #### Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(southern_df["Lat"], southern_df["Humidity"])

# Call an function #2
annotate(equation, -50, 30)

# Set title
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("OutputData/Humidity_vs_Latitude_Southern_Regression.png")
# Out:
# The r-squared is : 0.22

# %% [markdown]
# ##### This code is analyzing the relationship between the Latitude and the Humidity in the Southern Hemisphere. The low correlation shown suggests that there is no correlation between the Latitude and the Humidity.

# %% [markdown]
# #### Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(northern_df["Lat"], northern_df["Cloudiness"])

# Call an function #2
annotate(equation, 30, 40)

# Set a title
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("OutputData/Cloudiness_vs_Latitude_Northern_Regression.png")
# Out:
# The r-squared is : 0.05

# %% [markdown]
# ##### This code is analyzing the relationship between the Latitude and the Cloudiness in the Northern Hemisphere. The low correlation shown suggests that there is no correlation between the Latitude and the Cloudiness.

# %% [markdown]
# #### Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(southern_df["Lat"], southern_df["Cloudiness"])

# Call an function #2
annotate(equation, -50, 15)

# Set a title
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("OutputData/Cloudiness_vs_Latitude_Southern_Regression.png")
# Out:
# The r-squared is : 0.07

# %% [markdown]
# ##### This code is analyzing the relationship between the Latitude and the Cloudiness in the Southern Hemisphere. The low correlation shown suggests that there is no correlation between the Latitude and the Cloudiness.

# %% [markdown]
# #### Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(northern_df["Lat"], northern_df["Wind Speed"])

# Call an function #2
annotate(equation, 40, 25)

# Set  title
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("OutputData/Wind_Speed_vs_Latitude_Northern_Regression.png")
# Out:
# The r-squared is : 0.02

# %% [markdown]
# ##### This code is analyzing the relationship between the Latitude and the Wind Speed in the Northern Hemisphere. The low correlation shown suggests that there is no correlation between the Latitude and the Windspeed.

# %% [markdown]
# #### Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(southern_df["Lat"], southern_df["Wind Speed"])

# Call an function #2
annotate(equation, -30, 22)

# Set  title
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("OutputData/Wind_Speed_vs_Latitude_Southern_Regression.png")
# Out:
# The r-squared is : -0.22

# %% [markdown]
# ##### This code is analyzing the relationship between the Latitude and the Wind Speed in the Southern Hemisphere. The low correlation shown suggests that there is no correlation between the Latitude and the Windspeed.
