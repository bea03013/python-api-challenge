# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress


# Import API key
#from api_keys import weather_api_key
weather_api_key = "514bff03b058e553c98b7ba1ccae1db2"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "OutputData/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 595

# %% [markdown]
# ## Perform API Calls
# ##### Perform a weather check on each city using a series of successive API calls.
# ##### Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"----------------------------------------------------------")
print(f"Beginning Data Retrieval")
print(f"----------------------------------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# ----------------------------------------------------------
# Beginning Data Retrieval
# ----------------------------------------------------------
# Processing Record 1 | Sakakah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=sakakah
# Processing Record 2 | Waddān
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=waddan
# Processing Record 3 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ushuaia
# Processing Record 4 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=qaanaaq
# Processing Record 5 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=atuona
# Processing Record 6 | Severo-Kuril'sk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=severo-kurilsk
# Processing Record 7 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=mataura
# Processing Record 8 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=rikitea
# Processing Record 9 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=new norfolk
# Processing Record 10 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bethel
# Processing Record 11 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=thompson
# Processing Record 12 | Kamenka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kamenka
# Processing Record 13 | Sainte-Anne-des-Monts
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=sainte-anne-des-monts
# Processing Record 14 | Cockburn Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=cockburn town
# City not found. Skipping...
# Processing Record 15 | São Filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=sao filipe
# City not found. Skipping...
# Processing Record 16 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=saint-philippe
# Processing Record 17 | Mahendranagar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=mahendranagar
# Processing Record 18 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=avarua
# Processing Record 19 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=torbay
# City not found. Skipping...
# Processing Record 20 | Necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=necochea
# Processing Record 21 | Paracatu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=paracatu
# Processing Record 22 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=hithadhoo
# Processing Record 23 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=lebu
# City not found. Skipping...
# Processing Record 24 | Dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=dunedin
# Processing Record 25 | Vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=vostok
# Processing Record 26 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=hermanus
# Processing Record 27 | Tagusao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tagusao
# Processing Record 28 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=guerrero negro
# Processing Record 29 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=lompoc
# Processing Record 30 | Spearfish
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=spearfish
# Processing Record 31 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tasiilaq
# Processing Record 32 | San Miguel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=san miguel
# Processing Record 33 | Grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=grindavik
# Processing Record 34 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=east london
# Processing Record 35 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=busselton
# Processing Record 36 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=butaritari
# Processing Record 37 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=vaini
# Processing Record 38 | Barentu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=barentu
# Processing Record 39 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=mar del plata
# Processing Record 40 | Cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=cayenne
# Processing Record 41 | Artyom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=artyom
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=cape town
# Processing Record 43 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=punta arenas
# Processing Record 44 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=albany
# Processing Record 45 | Marzuq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=marzuq
# City not found. Skipping...
# Processing Record 46 | Taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=taltal
# Processing Record 47 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=upernavik
# Processing Record 48 | Mitú
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=mitu
# Processing Record 49 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=hobart
# Processing Record 50 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=leningradskiy
# Processing Record 51 | Sabirabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=sabirabad
# City not found. Skipping...
# Processing Record 52 | Buta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=buta
# City not found. Skipping...
# Processing Record 53 | Comodoro Rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=comodoro rivadavia
# Processing Record 54 | Yangi Marg`ilon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=komsomolskiy
# Processing Record 55 | Jardim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=jardim
# Processing Record 56 | Slave Lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=slave lake
# City not found. Skipping...
# Processing Record 57 | Imeni Poliny Osipenko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=imeni poliny osipenko
# Processing Record 58 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bredasdorp
# Processing Record 59 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bluff
# Processing Record 60 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=khatanga
# Processing Record 61 | Touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=touros
# Processing Record 62 | Constitución
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=constitucion
# Processing Record 63 | Mahon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=mao
# Processing Record 64 | Tezu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tezu
# Processing Record 65 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=yellowknife
# Processing Record 66 | Zabaykal'sk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=zabaykalsk
# City not found. Skipping...
# Processing Record 67 | Pathein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=pathein
# Processing Record 68 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=hambantota
# Processing Record 69 | Darhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=darhan
# Processing Record 70 | Malbork
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=marienburg
# Processing Record 71 | La Ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=la ronge
# Processing Record 72 | Riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=riyadh
# Processing Record 73 | Senno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=senno
# Processing Record 74 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kapaa
# Processing Record 75 | Honiara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=honiara
# Processing Record 76 | Beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=beloha
# City not found. Skipping...
# Processing Record 77 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=narsaq
# Processing Record 78 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=castro
# City not found. Skipping...
# Processing Record 79 | Acapulco de Juárez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=acapulco
# Processing Record 80 | Brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=brae
# Processing Record 81 | Tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tessalit
# Processing Record 82 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=jamestown
# Processing Record 83 | General Pico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=general pico
# Processing Record 84 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bambous virieux
# Processing Record 85 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=dikson
# Processing Record 86 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=vila velha
# Processing Record 87 | Flic en Flac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=flic en flac
# Processing Record 88 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=faanui
# Processing Record 89 | Pareora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=pareora
# Processing Record 90 | Adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=adrar
# Processing Record 91 | Yokadouma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=yokadouma
# Processing Record 92 | San Cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=san cristobal
# Processing Record 93 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=chokurdakh
# Processing Record 94 | Luzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=luzhou
# Processing Record 95 | Anastasiyevskaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=anastasiyevskaya
# Processing Record 96 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=port elizabeth
# Processing Record 97 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=barrow
# Processing Record 98 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=saint george
# Processing Record 99 | Rome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=roma
# Processing Record 100 | Lesosibirsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=lesosibirsk
# Processing Record 101 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=airai
# Processing Record 102 | Alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=alofi
# City not found. Skipping...
# Processing Record 103 | Omboué
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=omboue
# Processing Record 104 | Santo Tomas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=santo tomas
# Processing Record 105 | Kimamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kimamba
# City not found. Skipping...
# Processing Record 106 | Bayonet Point
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bayonet point
# Processing Record 107 | Kasongo-Lunda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kasongo-lunda
# Processing Record 108 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=port alfred
# Processing Record 109 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ahipara
# Processing Record 110 | Mahébourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=mahebourg
# Processing Record 111 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bathsheba
# Processing Record 112 | Mazyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=mazyr
# Processing Record 113 | Baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=baykit
# Processing Record 114 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=puerto ayora
# Processing Record 115 | Yeppoon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=yeppoon
# Processing Record 116 | Christchurch
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=christchurch
# Processing Record 117 | Khasan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=khasan
# Processing Record 118 | Vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=vanimo
# Processing Record 119 | Saint Paul Harbor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kodiak
# Processing Record 120 | Evensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=evensk
# Processing Record 121 | Kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kununurra
# Processing Record 122 | Salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=salalah
# City not found. Skipping...
# Processing Record 123 | Havøysund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=havoysund
# Processing Record 124 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=cidreira
# City not found. Skipping...
# Processing Record 125 | Turukhansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=turukhansk
# Processing Record 126 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=nikolskoye
# Processing Record 127 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=norman wells
# Processing Record 128 | Umluj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=umm lajj
# City not found. Skipping...
# Processing Record 129 | Tchaourou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tchaourou
# Processing Record 130 | Husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=husavik
# Processing Record 131 | Gaza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=gasa
# City not found. Skipping...
# Processing Record 132 | Jutaí
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=jutai
# Processing Record 133 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=saldanha
# Processing Record 134 | Roald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=roald
# Processing Record 135 | Miklavž na Dravskem Polju
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=miklavz na dravskem polju
# Processing Record 136 | Rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=rawson
# Processing Record 137 | Isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=isangel
# Processing Record 138 | Kosonsoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kosonsoy
# Processing Record 139 | Isla Mujeres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=isla mujeres
# Processing Record 140 | Tarija
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tarija
# Processing Record 141 | Garissa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=garissa
# Processing Record 142 | Goya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=goya
# Processing Record 143 | Rockingham
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=rockingham
# Processing Record 144 | Chapada dos Guimarães
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=chapada dos guimaraes
# Processing Record 145 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=pevek
# Processing Record 146 | İzmit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=izmit
# Processing Record 147 | George Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=georgetown
# Processing Record 148 | Inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=inhambane
# Processing Record 149 | Yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=yumen
# Processing Record 150 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ribeira grande
# Processing Record 151 | Natchez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=natchez
# Processing Record 152 | Bulgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bulgan
# City not found. Skipping...
# Processing Record 153 | Timrå
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=timra
# Processing Record 154 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=los llanos de aridane
# Processing Record 155 | Rawlins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=rawlins
# Processing Record 156 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=te anau
# Processing Record 157 | Rameswaram
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=rameswaram
# City not found. Skipping...
# Processing Record 158 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=cherskiy
# Processing Record 159 | Skegness
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=skegness
# Processing Record 160 | Saint-Augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=saint-augustin
# Processing Record 161 | Luganville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=luganville
# Processing Record 162 | Flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=flinders
# Processing Record 163 | Avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=avera
# Processing Record 164 | Santiago
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=santiago
# Processing Record 165 | Chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=chapais
# Processing Record 166 | Lagunas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=lagunas
# Processing Record 167 | Samarinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=samarinda
# Processing Record 168 | Makat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=makat
# Processing Record 169 | Port-Gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=port-gentil
# Processing Record 170 | Bremerton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bremerton
# Processing Record 171 | Shingū
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=shingu
# Processing Record 172 | Terenos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=terenos
# Processing Record 173 | Ballina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ballina
# City not found. Skipping...
# Processing Record 174 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tuktoyaktuk
# City not found. Skipping...
# Processing Record 175 | Pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=pisco
# Processing Record 176 | Kenai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kenai
# Processing Record 177 | Ottawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ottawa
# Processing Record 178 | Santa Isabel Rio Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=santa isabel do rio negro
# Processing Record 179 | Hay River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=hay river
# Processing Record 180 | Kerrobert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kerrobert
# Processing Record 181 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kahului
# Processing Record 182 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kaitangata
# Processing Record 183 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=provideniya
# Processing Record 184 | Elk City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=elk city
# Processing Record 185 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ponta do sol
# Processing Record 186 | Tromsø
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tromso
# Processing Record 187 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=geraldton
# Processing Record 188 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=san patricio
# Processing Record 189 | Bloomingdale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bloomingdale
# Processing Record 190 | Abu Dhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=abu dhabi
# Processing Record 191 | Fort Nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=fort nelson
# Processing Record 192 | Licata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=licata
# Processing Record 193 | Boueni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=boueni
# Processing Record 194 | Fountain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=fountain
# Processing Record 195 | Colares
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=colares
# City not found. Skipping...
# Processing Record 196 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=caravelas
# Processing Record 197 | Philadelphia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=filadelfia
# Processing Record 198 | Hammerfest
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=hammerfest
# Processing Record 199 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=longyearbyen
# Processing Record 200 | Sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=sitka
# Processing Record 201 | Changzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=changzhou
# Processing Record 202 | Wawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=wawa
# Processing Record 203 | Semporna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=semporna
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 204 | Mossamedes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=namibe
# Processing Record 205 | Laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=laguna
# Processing Record 206 | Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=lavrentiya
# Processing Record 207 | Souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=souillac
# Processing Record 208 | Hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=hualmay
# Processing Record 209 | Dali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=dali
# Processing Record 210 | Bilibino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bilibino
# Processing Record 211 | Nyaunglebin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=nyaunglebin
# Processing Record 212 | Okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=okhotsk
# Processing Record 213 | Piaçabuçu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=piacabucu
# Processing Record 214 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tiksi
# Processing Record 215 | Chenghai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=chenghai
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 216 | Porto Velho
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=porto velho
# Processing Record 217 | Taunggyi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=taunggyi
# Processing Record 218 | Manono
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=manono
# Processing Record 219 | Praia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=praia
# Processing Record 220 | De Aar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=de aar
# Processing Record 221 | Qala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=qala
# City not found. Skipping...
# Processing Record 222 | Krasnosel'kup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=krasnoselkup
# Processing Record 223 | Copiapó
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=copiapo
# Processing Record 224 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=fortuna
# Processing Record 225 | Tucupita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tucupita
# Processing Record 226 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=cabo san lucas
# Processing Record 227 | Maniitsoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=maniitsoq
# Processing Record 228 | Namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=namatanai
# Processing Record 229 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kruisfontein
# Processing Record 230 | Oistins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=oistins
# Processing Record 231 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=aklavik
# Processing Record 232 | Fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=fairbanks
# Processing Record 233 | Carupano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=carupano
# Processing Record 234 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=esperance
# Processing Record 235 | Banepā
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=banepa
# Processing Record 236 | Antofagasta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=antofagasta
# Processing Record 237 | Bonavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bonavista
# Processing Record 238 | Ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ugoofaaru
# Processing Record 239 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=nanortalik
# Processing Record 240 | Casper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=casper
# Processing Record 241 | Antsohihy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=antsohihy
# Processing Record 242 | Lewisporte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=lewisporte
# Processing Record 243 | Manzhouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=manzhouli
# Processing Record 244 | Erenhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=erenhot
# Processing Record 245 | Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=saint-pierre
# Processing Record 246 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kavaratti
# Processing Record 247 | Hong Kong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=victoria
# Processing Record 248 | Turka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=turka
# Processing Record 249 | Talas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=talas
# Processing Record 250 | Saint Anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=saint anthony
# Processing Record 251 | Mahon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=mahon
# Processing Record 252 | Arman'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=arman
# Processing Record 253 | Mujiayingzi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=mujiayingzi
# Processing Record 254 | Viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=viedma
# Processing Record 255 | Omsukchan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=omsukchan
# Processing Record 256 | Kendari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kendari
# Processing Record 257 | Dekar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=dekar
# Processing Record 258 | Ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ambilobe
# Processing Record 259 | Tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tautira
# City not found. Skipping...
# Processing Record 260 | Codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=codrington
# Processing Record 261 | Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ostrovnoy
# Processing Record 262 | Talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=talnakh
# City not found. Skipping...
# Processing Record 263 | Constantine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=constantine
# Processing Record 264 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=carnarvon
# Processing Record 265 | Kaa-Khem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kaa-khem
# Processing Record 266 | Skjervøy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=skjervoy
# Processing Record 267 | Benguela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=benguela
# Processing Record 268 | Suifenhe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=suifenhe
# Processing Record 269 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tuatapere
# Processing Record 270 | Kampene
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kampene
# Processing Record 271 | Jhanjhārpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=jhanjharpur
# Processing Record 272 | Ziro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ziro
# Processing Record 273 | Pacific Grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=pacific grove
# Processing Record 274 | Fort Madison
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=fort madison
# Processing Record 275 | Boyarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=boyarka
# Processing Record 276 | Apac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=apac
# Processing Record 277 | Great Falls
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=great falls
# Processing Record 278 | Luxor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=luxor
# Processing Record 279 | North Bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=north bend
# Processing Record 280 | Udachny
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=udachnyy
# Processing Record 281 | Waingapu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=waingapu
# Processing Record 282 | Santa Cruz de la Sierra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=santa cruz
# Processing Record 283 | Belaya Gora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=belaya gora
# City not found. Skipping...
# Processing Record 284 | Bāglung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=baglung
# Processing Record 285 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=hilo
# City not found. Skipping...
# Processing Record 286 | College
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=college
# Processing Record 287 | Ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ancud
# Processing Record 288 | Bairiki Village
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bairiki
# Processing Record 289 | Sørland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=sorland
# Processing Record 290 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=arraial do cabo
# Processing Record 291 | Wainwright
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=wainwright
# Processing Record 292 | Bogotol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bogotol
# Processing Record 293 | Kampong Chhnang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kampong chhnang
# Processing Record 294 | Olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=olafsvik
# Processing Record 295 | Maxixe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=maxixe
# Processing Record 296 | Racine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=racine
# City not found. Skipping...
# Processing Record 297 | Bashmakovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bashmakovo
# Processing Record 298 | Blagoyevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=blagoyevo
# Processing Record 299 | Sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=sinnamary
# Processing Record 300 | Iroquois Falls
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=iroquois falls
# Processing Record 301 | Agadez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=agadez
# Processing Record 302 | Cape Canaveral
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=cape canaveral
# Processing Record 303 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=coquimbo
# Processing Record 304 | Bom Jesus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bom jesus
# Processing Record 305 | Klaksvík
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=klaksvik
# Processing Record 306 | Ihosy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ihosy
# Processing Record 307 | Malanje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=malanje
# Processing Record 308 | San Quintín
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=san quintin
# Processing Record 309 | Saint-Gabriel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=saint-gabriel
# Processing Record 310 | Kaohsiung City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kaohsiung
# Processing Record 311 | Baghdad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=baghdad
# Processing Record 312 | Lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=lagoa
# Processing Record 313 | Rockport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=rockport
# Processing Record 314 | Kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kalmunai
# Processing Record 315 | Manggar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=manggar
# Processing Record 316 | Aswān
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=aswan
# Processing Record 317 | Aksarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=aksarka
# Processing Record 318 | Tripoli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tripoli
# Processing Record 319 | Benjamín Aceval
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=benjamin aceval
# City not found. Skipping...
# Processing Record 320 | Hervey Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=hervey bay
# Processing Record 321 | Kayes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kayes
# Processing Record 322 | Port Lincoln
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=cravo norte
# Processing Record 443 | Tabuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tabuk
# Processing Record 444 | Padampur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=padampur
# Processing Record 445 | Alice Springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=alice springs
# Processing Record 446 | Bwanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bwanga
# Processing Record 447 | Thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=thinadhoo
# Processing Record 448 | Zhangye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=zhangye
# Processing Record 449 | Kimbe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kimbe
# Processing Record 450 | Goma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=goma
# Processing Record 451 | Storsteinnes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=storsteinnes
# Processing Record 452 | Mackay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=mackay
# Processing Record 453 | Ponta Delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ponta delgada
# City not found. Skipping...
# Processing Record 454 | Port-Cartier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=port-cartier
# Processing Record 455 | Nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=nantucket
# Processing Record 456 | Rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=rocha
# Processing Record 457 | Stephenville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=stephenville
# Processing Record 458 | Biltine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=biltine
# Processing Record 459 | Polson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=polson
# Processing Record 460 | Fichē
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=fiche
# Processing Record 461 | San Miguel de Tucumán
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tucuman
# Processing Record 462 | Yiyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=yiyang
# Processing Record 463 | Luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=luanda
# Processing Record 464 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=iqaluit
# Processing Record 465 | Padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=padang
# Processing Record 466 | Chui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=chuy
# Processing Record 467 | San Nicolas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=san nicolas
# Processing Record 468 | Valea Crişului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=valea crisului
# Processing Record 469 | Tam Ky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tam ky
# Processing Record 470 | Basco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=basco
# Processing Record 471 | Itoman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=itoman
# Processing Record 472 | Natal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=natal
# Processing Record 473 | Nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=nome
# Processing Record 474 | Oktyabr'skoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=oktyabrskoye
# Processing Record 475 | Akdepe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=akdepe
# Processing Record 476 | Nizhnyaya Tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=nizhnyaya tura
# Processing Record 477 | Gigmoto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=gigmoto
# Processing Record 478 | Kuching
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kuching
# City not found. Skipping...
# Processing Record 479 | Zilina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=zilina
# Processing Record 480 | Phan Thiet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=phan thiet
# Processing Record 481 | Ritchie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ritchie
# Processing Record 482 | Okato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=okato
# Processing Record 483 | Barranca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=barranca
# Processing Record 484 | Hailar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=hailar
# Processing Record 485 | Kumul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=hami
# Processing Record 486 | Sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=sisimiut
# Processing Record 487 | La Tuque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=la tuque
# Processing Record 488 | Tarko-Sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=tarko-sale
# Processing Record 489 | Kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kieta
# Processing Record 490 | Vilyuysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=vilyuysk
# Processing Record 491 | Strathmore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=strathmore
# Processing Record 492 | Sangar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=sangar
# Processing Record 493 | Leopold
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=leopold
# Processing Record 494 | Neiafu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=neiafu
# Processing Record 495 | Haines Junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=haines junction
# City not found. Skipping...
# Processing Record 496 | Hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=hofn
# Processing Record 497 | Akureyri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=akureyri
# Processing Record 498 | Northport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=northport
# Processing Record 499 | Lamu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=lamu
# Processing Record 500 | Auki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=auki
# Processing Record 501 | Lüderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=luderitz
# Processing Record 502 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=mount gambier
# Processing Record 503 | Maryborough
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=maryborough
# Processing Record 504 | Luau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=luau
# Processing Record 505 | Chipinge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=chipinge
# Processing Record 506 | Springfield
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=springfield
# Processing Record 507 | Srikakulam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=srikakulam
# Processing Record 508 | Palmas Bellas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=palmas bellas
# Processing Record 509 | Kiryat Gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=gat
# Processing Record 510 | Innisfail
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=innisfail
# Processing Record 511 | Pontal do Paraná
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=pontal do parana
# Processing Record 512 | Obihiro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=obihiro
# Processing Record 513 | Hinton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=hinton
# Processing Record 514 | Abilene
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=abilene
# Processing Record 515 | Kushima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kushima
# Processing Record 516 | Adzopé
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=adzope
# Processing Record 517 | Balangiga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=balangiga
# Processing Record 518 | Peace River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=peace river
# Processing Record 519 | Sioux Lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=sioux lookout
# Processing Record 520 | São José de Ribamar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=sao jose de ribamar
# Processing Record 521 | Ambon City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ambon
# Processing Record 522 | Gucheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=gucheng
# Processing Record 523 | Bucerías
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=bucerias
# Processing Record 524 | Ginir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ginir
# City not found. Skipping...
# Processing Record 525 | Phek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=phek
# Processing Record 526 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=katsuura
# Processing Record 527 | Valparaíso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=valparaiso
# Processing Record 528 | Hatillo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=hatillo
# Processing Record 529 | Zeya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=zeya
# Processing Record 530 | Araranguá
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ararangua
# City not found. Skipping...
# Processing Record 531 | Aban
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=aban
# Processing Record 532 | Castelo Branco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=castelo branco
# Processing Record 533 | Meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=meulaboh
# Processing Record 534 | Santa Rosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=santa rosa
# Processing Record 535 | Oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=oranjemund
# Processing Record 536 | Buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=buala
# Processing Record 537 | Līsakovsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=lisakovsk
# Processing Record 538 | Aripuanã
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=aripuana
# Processing Record 539 | Okha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=okha
# Processing Record 540 | Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=srednekolymsk
# City not found. Skipping...
# Processing Record 541 | Sabzawār
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=sabzevar
# Processing Record 542 | Aras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=aras
# Processing Record 543 | Leningradskaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=leningradskaya
# Processing Record 544 | Harrison
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=harrison
# Processing Record 545 | Nova Olímpia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=nova olimpia
# Processing Record 546 | Pundaguitan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=pundaguitan
# Processing Record 547 | Ishigaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=ishigaki
# Processing Record 548 | Kachīry
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=kachiry
# Processing Record 549 | Morón
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=moron
# Processing Record 550 | Pangody
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=514bff03b058e553c98b7ba1ccae1db2&q=pangody

# %% [markdown]
# ## Convert Raw Data to DataFrame
# ##### Export the city data into a .csv.
# ##### Display the DataFrame

# %%
# Create a dictonary with the lists generated
weatherpy_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a data frame from dictionary
weather_df = pd.DataFrame(weatherpy_dict)

# Display count of weather data values to look for any missing data...looks like we're good! 
weather_df.count()
# Out:
# City          550
# Cloudiness    550
# Country       550
# Date          550
# Humidity      550
# Lat           550
# Lng           550
# Max Temp      550
# Wind Speed    550
# dtype: int64

# %%
# Save data frame to CSV
weather_df.to_csv('OutputData/weather_data.csv')

# Display data frame head 
weather_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-5425b320b829> in <module>
#       1 # Save data frame to CSV
# ----> 2 weather_df.to_csv('OutputData/weather_data.csv')
#       3
#       4 # Display data frame head
#       5 weather_df.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     186                 self.mode,
#     187                 encoding=self.encoding,
# --> 188                 compression=dict(self.compression_args, method=self.compression),
#     189             )
#     190             close = True
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     426         if encoding:
#     427             # Encoding
# --> 428             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     429         elif is_text:
#     430             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'OutputData/weather_data.csv'

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ##### Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
#First sort descending by Humidty
humidity_df = weather_df.sort_values(["Humidity"], ascending=False)
humidity_df.head()

# %% [markdown]
# #### It looks like there are no cities with a humidity over 100...so we can skip the next step!

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

clean_city_df = weather_df

clean_city_df.head()

# %%
# Extract relevant fields from the data frame
clean_city_df = clean_city_df[["City", "Cloudiness", "Humidity", "Lat", "Lng", "Max Temp", "Wind Speed"]]


# Export the City_Data into a csv
clean_city_df.to_csv("OutputData/CleanCityData.csv", index=True, header=True)

# %% [markdown]
# ## Plotting the Data
# ##### Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# ##### Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature

# %%
# Build a scatter plot for each data type
plt.scatter(clean_city_df["Lat"], clean_city_df["Max Temp"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("OutputData/Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ##### This code is analyzing the relationship between the Latitude and the Max Temperature. It appears to show that max temperature peaks around 20 degrees Latitude and then goes down the farther you get from there.

# %% [markdown]
# ## Latitude vs. Humidity

# %%
# Build a scatter plot for each data type
plt.scatter(clean_city_df["Lat"], clean_city_df["Humidity"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("OutputData/Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ##### This code is analyzing the relationship between the Latitude and the Humidity. It appears to show that there is no correlation between the two.

# %% [markdown]
# ## Latitude vs. Cloudiness

# %%
# Build a scatter plot for each data type
plt.scatter(clean_city_df["Lat"], clean_city_df["Cloudiness"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("OutputData/Cloudiness_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ##### This code is analyzing the relationship between the Latitude and the Cloudiness. It appears to show that there is no correlation between the two.

# %% [markdown]
# ## Latitude vs. Windspeed

# %%
# Build a scatter plot for each data type
plt.scatter(clean_city_df["Lat"], clean_city_df["Wind Speed"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("OutputData/Wind_Speed_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ##### This code is analyzing the relationship between the Latitude and the Max Temperature. It appears to show that there is no correlation between the two.

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames

northern_df = clean_city_df.loc[clean_city_df["Lat"] >= 0]
southern_df = clean_city_df.loc[clean_city_df["Lat"] < 0]

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def linear_regression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Define a fuction for annotating
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %% [markdown]
# #### Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(northern_df["Lat"], northern_df["Max Temp"])

# Call an function #2
annotate(equation, 10, 40)

# Set a title
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("OutputData/Max_Temp_vs_Latitude_Northern_Regression.png")

# %% [markdown]
# ##### This code is analyzing the relationship between the Latitude and the Max Temperature in the Norther Hemisphere. It appears to show that max temperature peaks around 20 degrees Latitude and then goes down the farther you get from there. The higher negative r value shows that there is a decent amount of correlation between the Latitude and the Max Temperature. The higher the Latitude, the lower the Max Temperature in general.

# %% [markdown]
# #### Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(southern_df["Lat"],southern_df["Max Temp"])

# Call an function #2
annotate(equation, -30, 50)

# Set a title
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("OutputData/Max_Temp_vs_Latitude_Southern_Regression.png")

# %% [markdown]
# ##### This code is analyzing the relationship between the Latitude and the Max Temperature in the Southern Hemisphere. It appears to show that max temperature peaks the closer to Latitude 0 degrees. The higher r value shows that there is a decent amount of correlation between the Latitude and the Max Temperature. The closer to 0 the Latitude gets, the higher the Max Temperature in general.

# %% [markdown]
# #### Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(northern_df["Lat"], northern_df["Humidity"])

# Call an function #2
annotate(equation, 40, 15)

# Set a title
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("OutputData/Humidity_vs_Latitude_Northern_Regression.png")

# %% [markdown]
# ##### This code is analyzing the relationship between the Latitude and the Humidity in the Northern Hemisphere. The low correlation shown suggests that there is no correlation between the Latitude and the Humidity.

# %% [markdown]
# #### Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(southern_df["Lat"], southern_df["Humidity"])

# Call an function #2
annotate(equation, -50, 30)

# Set title
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("OutputData/Humidity_vs_Latitude_Southern_Regression.png")

# %% [markdown]
# ##### This code is analyzing the relationship between the Latitude and the Humidity in the Southern Hemisphere. The low correlation shown suggests that there is no correlation between the Latitude and the Humidity.

# %% [markdown]
# #### Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(northern_df["Lat"], northern_df["Cloudiness"])

# Call an function #2
annotate(equation, 30, 40)

# Set a title
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("OutputData/Cloudiness_vs_Latitude_Northern_Regression.png")

# %% [markdown]
# ##### This code is analyzing the relationship between the Latitude and the Cloudiness in the Northern Hemisphere. The low correlation shown suggests that there is no correlation between the Latitude and the Cloudiness.

# %% [markdown]
# #### Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(southern_df["Lat"], southern_df["Cloudiness"])

# Call an function #2
annotate(equation, -50, 15)

# Set a title
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("OutputData/Cloudiness_vs_Latitude_Southern_Regression.png")

# %% [markdown]
# ##### This code is analyzing the relationship between the Latitude and the Cloudiness in the Southern Hemisphere. The low correlation shown suggests that there is no correlation between the Latitude and the Cloudiness.

# %% [markdown]
# #### Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(northern_df["Lat"], northern_df["Wind Speed"])

# Call an function #2
annotate(equation, 40, 25)

# Set  title
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("OutputData/Wind_Speed_vs_Latitude_Northern_Regression.png")

# %% [markdown]
# ##### This code is analyzing the relationship between the Latitude and the Wind Speed in the Northern Hemisphere. The low correlation shown suggests that there is no correlation between the Latitude and the Windspeed.

# %% [markdown]
# #### Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(southern_df["Lat"], southern_df["Wind Speed"])

# Call an function #2
annotate(equation, -30, 22)

# Set  title
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("OutputData/Wind_Speed_vs_Latitude_Southern_Regression.png")

# %% [markdown]
# ##### This code is analyzing the relationship between the Latitude and the Wind Speed in the Southern Hemisphere. The low correlation shown suggests that there is no correlation between the Latitude and the Windspeed.
